# %%
products = ["knife" , "lighter", "pen", "brush", "notebook", "photo"]
sample_products = ("Product Name", "Price", "Category")

# %%
products[1]
# Out:
# 'lighter'

# %%
products[5]
# Out:
# 'photo'

# %%
products.append("phone")
products.append("laptop")

# %%
products
# Out:
# ['knife', 'lighter', 'pen', 'brush', 'notebook', 'photo', 'phone', 'laptop']

# %%
categories_set = {"Stationary", "Electronics", "Clothing", "Food", "Toys", "Furniture", "Sports", "Health", "Beauty", "Automotive"}
categories_set.add("Books")
categories_set
# Out:
# {'Books', 'Clothing', 'Electronics', 'Food', 'Stationary', 'Toys'}

# %%
price_dict = {"knife": 10, "lighter": 5, "pen": 2, "brush": 8, "notebook": 15, "photo": 20}
price_dict["phone"] = 100
del price_dict["lighter"]
print(price_dict)
# Out:
# {'knife': 10, 'pen': 2, 'brush': 8, 'notebook': 15, 'photo': 20, 'phone': 100}
