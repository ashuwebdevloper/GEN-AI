# %% [markdown]
# ## Key Concepts of Enscapsulation
#
# 1. Public Members
# 2. Protected Members
# 3. Private Members
# 4. Getter and setter methods

# %%
class Ironman:
    def __init__ (self,name,power,weapon):
        self.power = power
        self.weapon = weapon
        self.name = name
    
    def introduction(self):
        print(f"Hello my name is{self.name} and i have {self.power}")

# %%
iron = Ironman("Ashish", "Genius ", "Repulsor beam")

# %%
dir(iron)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'introduction',
#  'name',
#  'power',
#  'weapon']

# %%
## Private mebers a thi sis not accesible to autsiede the class and not even in the deric=veed class


## private memeber sare decleared by double underscore before the name

# %%
class Avenger:
    def __init__(self,name,phone_number):
        self.name = name
        self.__phone_number = phone_number

# %%
avenge=Avenger("captain","6387518744")

# %%
avenge.phone_number
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 avenge.phone_number
#
# AttributeError: 'Avenger' object has no attribute 'phone_number'

# %%
dir(avenge)
# Out:
# ['_Avenger__phone_number',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name']

# %%
class Captain:
    def __init__(self,name,phone_number):
        self.name = name
        self.__phone_number = phone_number

    def accessing_add(self)

# %%
class  Animal:
    def __init__(self,name,sound):
        self.name = name
        self.__sound = sound

    def sound_modify(self,new_sound):
        self,__sound=new_sound
    print(f"New sound for the animal is : {self.__sound}")
# Out:
#   Cell In[15], line 2
#     def __init__(self,name,sound):
#     ^
# IndentationError: expected an indented block after class definition on line 1

# %%
class Grandparent:
    def __init__(self,name,locker_key):
        self.name = name
        self.__locker_key = locker_key

    def locker_info(self):
        print(f"The locker key info is {self._locker_key}")

# %%
class parent(Grandparent):
    def __init__(self,name,locker_key):
        super().__init__(name.locker_key)

    def child_reveals(self):
        print(f"The locker key info is revelaed by {self._locker_key}")

# %%
## whole process pf encapsulation

## bank account sustem example

# %%
class BankAccount:
    def __init__(self,account_holder,balance):
        self.account_holder= account_holder
        self.__balance = balance

    def get_balnce(self):
        print(f"my balance is :{self._balance}")
    def deposit(Self,amount):
        if amount>0:
            self._balance+=amount


            return f"deposited amount is {self.get_balance()}"
        else:
            return f"deposited amount must be positive"
        
    def withdraw(self,withdraw):
        if amount<self.__balance:
            self.__balance=amount
            return f"withdrawl {amount} is   : {Self.get_balance()}:"
        
        else:
            return f"insufficient funds in acccounnt"

# %%
account = BankAccount("Ashsih",10000)

# %%
account.balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 account.balance
#
# AttributeError: 'BankAccount' object has no attribute 'balance'

# %%
account.account_holder
# Out:
# 'Ashsih'
