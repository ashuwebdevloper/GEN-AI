# %% [markdown]
# ## Numpy, pandas , matplolib, seaborn all libraries are required

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns   
import plotly.express as px

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.1 is available.
# You should consider upgrading via the 'c:\Users\aboyc\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_csv('C:\\Users\\aboyc\\tutedude\\Seaborn\\student_depression_dataset.csv')
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
df2 = pd.read_csv('C:\\Users\\aboyc\\tutedude\\Seaborn\\Chocolate Sales.csv')
df2.head()
# Out:
#      Sales Person    Country              Product       Date    Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1     Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2    Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %%
sns.lineplot(data=df, x='Age', y='Depression')
# Out:
# <Axes: xlabel='Age', ylabel='Depression'>

# %%
sns.relplot(data=df, x='Age', y='CGPA', kind='line')

# %%
sns.relplot(data=df, x='Age', y='Depression', kind='line', hue='Gender')

# %%
sns.relplot(data=df, x='Age', y='CGPA', kind='line', style='Dietary Habits',hue='Dietary Habits')

# %%
tips =sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(data=tips, y='total_bill', x='day', hue='smoker', style='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.relplot(data=tips, x='day', y='total_bill', kind='line',hue='sex')

# %%
gap = px.data.gapminder()

# %%
gap.head(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
# 6  Afghanistan      Asia  1982   39.854  12881816  978.011439       AFG
# 7  Afghanistan      Asia  1987   40.822  13867957  852.395945       AFG
# 8  Afghanistan      Asia  1992   41.674  16317921  649.341395       AFG
# 9  Afghanistan      Asia  1997   41.763  22227415  635.341351       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# 5        4
# 6        4
# 7        4
# 8        4
# 9        4

# %%
gap.shape
# Out:
# (1704, 8)

# %%
gap['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
gap['continent'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', 'Oceania'], dtype=object)

# %%
gap['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
sns.lineplot(data=gap, x='year', y='lifeExp', hue='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
data = gap[gap['country'].isin(['India', 'United States', 'China', 'Germany', 'Brazil'])]

# %%
data
# Out:
#             country continent  year   lifeExp         pop     gdpPercap  \
# 168          Brazil  Americas  1952  50.91700    56602560   2108.944355
# 169          Brazil  Americas  1957  53.28500    65551171   2487.365989
# 170          Brazil  Americas  1962  55.66500    76039390   3336.585802
# 171          Brazil  Americas  1967  57.63200    88049823   3429.864357
# 172          Brazil  Americas  1972  59.50400   100840058   4985.711467
# 173          Brazil  Americas  1977  61.48900   114313951   6660.118654
# 174          Brazil  Americas  1982  63.33600   128962939   7030.835878
# 175          Brazil  Americas  1987  65.20500   142938076   7807.095818
# 176          Brazil  Americas  1992  67.05700   155975974   6950.283021
# 177          Brazil  Americas  1997  69.38800   168546719   7957.980824
# 178          Brazil  Americas  2002  71.00600   179914212   8131.212843
# 179          Brazil  Americas  2007  72.39000   190010647   9065.800825
# ...

# %%
sns.relplot(data=data, x='year', y='lifeExp', kind='line', hue='country')

# %%
sns.scatterplot(data=df, x='Age', y='CGPA')
# Out:
# <Axes: xlabel='Age', ylabel='CGPA'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='smoker', style='smoker', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter', hue='sex', style='smoker', size='size')

# %%
sns.scatterplot(data=gap, x='lifeExp', y='gdpPercap', hue='continent')
# Out:
# <Axes: xlabel='lifeExp', ylabel='gdpPercap'>

# %% [markdown]
# ## Facet Plot (Grid Plots)
# A Facet Plot allows us to split a single visualization into a grid of multiple subplots based on the unique categories of a categorical column.
# Why use Faceting instead of hue?
# When a categorical column has too many unique values, using hue overlays too many colors on a single graph, making it cluttered and unreadable.
#
# Faceting solves this by giving each category its own dedicated, clean subplot space.
#
# Key Mechanics:
# Row-wise or Column-wise Separation: We can split the information across rows, columns, or both using the row and col parameters.
#
# Figure-level Exclusive: As noted, faceting functionality is only possible using Figure-level functions (sns.relplot(), sns.displot(), sns.catplot()). It does not work with Axes-level functions (like sns.scatterplot()).

# %% [markdown]
# write about facet plot

# %%
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter', row='sex', style='day')

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.relplot(data=df, x='Age', y='CGPA', kind='line', col_wrap=2, col='Gender', hue='Dietary Habits', style='Dietary Habits' )

# %% [markdown]
# ## Distribution Plots
# Distribution plots provide an overview of how data is distributed within a given dataset—typically targeting a Numerical Column.
# Why use Distribution Plots?
# Univariate Analysis: Ideal for looking at a single variable in isolation to understand its natural behavior.
#
# Outlier Detection: Helps visually isolate extreme values (outliers) that lie far from the rest of the data.
#
# Shape and Spread Analysis: Gives instant insight into whether the data follows a Normal Distribution (bell curve) or is Skewed (left/right tail), alongside revealing its overall spread and central tendency.
#
# ### 1. Histplot (sns.histplot)
# A histogram checks the distribution of a numerical column by splitting the data into continuous, equal-interval intervals called bins. The height of each bar reflects the data count (frequency) within that specific interval.
# Function Type:
# Axes-Level Function: sns.histplot() (Draws directly onto an individual matplotlib axis)
#
# Syntax and Key Parameters:
# Python
# sns.histplot(data=df, x="column_name", bins=n, kde=True)
# data: The Pandas DataFrame containing your data.
#
# x: The specific numerical column_name you want to analyze.
#
# bins: Controls the resolution of your plot. You pass an integer n to specify the exact number of intervals you want inside the histogram.
#
# Too few bins over-summarizes the data (hiding patterns).
#
# Too many bins makes the plot jagged and noisy.
#
# kde: A boolean flag (True/False). When set to True, it overlays a smooth Kernel Density Estimate (KDE) curve right on top of the histogram bars to show the overall continuous trend.

# %%
df = pd.read_csv('C:\\Users\\aboyc\\tutedude\\Seaborn\\student_depression_dataset.csv')
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
sns.histplot(data=df, x='Age', bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Age', hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(data=df, x='Age', hue='Gender', kind='kde')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns

sns.kdeplot(data=tips, x='total_bill', hue='smoker', fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips, x='total_bill', hue='smoker', kind='kde', fill=True)

# %%
sns.regplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 1. Introduction to Categorical Plots
# Categorical plots are used when you want to visualize the relationship between a categorical variable (groups, categories, labels) and a numerical variable (counts, averages, distributions).
#
# In Seaborn, these plots are generally grouped under the figure-level function sns.catplot(), or you can use their specific axes-level functions directly.
#
# 2. Key Types of Categorical Plots
# A. Categorical Distribution Plots
# These plots show how numerical data is distributed across different categories.
#
# sns.boxplot() (Box Plot): * Shows the five-number summary: minimum, first quartile (Q25), median, third quartile (Q75), and maximum.
#
# Great for spotting outliers (points falling outside the whiskers).
#
# sns.violinplot() (Violin Plot):
#
# Combines a box plot with a Kernel Density Estimate (KDE).
#
# Shows the full distribution shape of the data along with the summary statistics.
#
# B. Categorical Estimate Plots (Aggregations)
# These plots automatically aggregate your data (usually calculating the mean / average) for each category.
#
# sns.barplot() (Bar Plot):
#
# The height of the bar represents the average value for that category.
#
# Includes error bars by default to show the confidence interval/variance of the data.
#
# sns.countplot() (Count Plot):
#
# A special type of bar plot that explicitly counts the number of occurrences (rows) for each category. Note: You only provide either an x or a y axis for this plot, not both.
#
# C. Categorical Scatter Plots
# These show every individual data point split into categories.
#
# sns.stripplot(): Plots all data points along the categorical axis. Points can overlap if the dataset is large.
#
# sns.swarmplot(): Similar to a strip plot, but automatically adjusts the points along the categorical axis so they do not overlap, giving a "swarm" or tree-like shape that reveals the density.

# %%
sns.clustermap(iris.iloc[:,0,1,2,3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sns.clustermap(iris.iloc[:,0,1,2,3])
#
# NameError: name 'iris' is not defined

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.barplot(data=gap, x='continent', y='lifeExp', estimator=np.mean)
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.barplot(data=gap, x='continent', y='gdpPercap', estimator=np.mean)
# Out:
# <Axes: xlabel='continent', ylabel='gdpPercap'>

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# ...

# %%
sns.barplot(data=df, x='Dietary Habits', y='Depression', estimator=np.mean, ci=None)
# Out:
# C:\Users\aboyc\AppData\Local\Temp\ipykernel_14136\1758173667.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Dietary Habits', y='Depression', estimator=np.mean, ci=None)
# <Axes: xlabel='Dietary Habits', ylabel='Depression'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(data=tips,x = 'sex', y='total_bill', estimator=np.mean, ci=None  , hue='smoker')
# Out:
# C:\Users\aboyc\AppData\Local\Temp\ipykernel_14136\906355492.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=tips,x = 'sex', y='total_bill', estimator=np.mean, ci=None  , hue='smoker')
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
sns.countplot(data=gap, x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
tips.head()

# %%
sns.countplot(data=tips, x='day')

# %%
## voilin plot
## x = categorical variable, y = numerical variable, hue = categorical variable
sns.violinplot(data=tips, x='total_bill',hue='sex')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.violinplot(data=gap, x='continent', y='lifeExp', hue='continent')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
## Swarmplot is used to show the distribution of data points in a categorical variable. It is similar to a scatter plot, but it shows the distribution of data points in a categorical variable. It is used to show the distribution of data points in a categorical variable. It is used to show the distribution of data points in a categorical variable 
## x = categorical variable, y = numerical variable, hue = categorical variable
sns.swarmplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
### regression plot shows the relationship between two numerical variables x and y along with the line of best fit
### x = numerical variable, y = numerical variable , hue = categorical variable 
### scatter plot shows the relationship between two numerical variables x and y without the line of best fit
### line plot can show us the future trend of the data

## example of regression plot: is there a relationship between total bill and tip? if yes then what is the line of best fit for this relationship?
sns.regplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
## multiplots shows the relationship between two numerical variables x and y along with the line of best fit for different categories of a categorical variable in a simialar way

## jon plot is used to show the distribution of data points in a numerical variable. It is similar to a histogram, but it shows the distribution of data points in a numerical variable. It is used to show the distribution of data points in a numerical variable. It is used to show the distribution of data points in a numerical variable 
## it is uselful when we have a large number of data points and we want to see the distribution of data points in a numerical variable. It is also useful when we want to see the distribution of data points in a numerical variable for different categories of a categorical variable. It is also useful when we want to see the distribution of data points in a numerical variable for different categories of a categorical variable along with the line of best fit for each category.  
## distribution of multiple categories of a categorical variable along with the line of best fit for each category relationship between total bill and tip for different categories of a categorical variable along with the line of best fit for each category 
sns.jointplot(data=tips, x='total_bill', y='tip', hue='smoker', kind='kde', fill=True)

# %%
## pair plot is used to show the relationship between multiple numerical variables in a dataset. It is similar to a scatter plot, but it shows the relationship between multiple numerical variables in a dataset. It is used to show the relationship between multiple numerical variables in a dataset. It is used to show the relationship between multiple numerical variables in a dataset along with the line of best fit for each pair of numerical variables. It is also useful when we want to see the relationship between multiple numerical variables in a dataset for different categories of a categorical variable along with the line of best fit for each pair of numerical variables for each category of a categorical variable. numerical columns in a dataset along with the line of best fit for each pair of numerical variables for each category of a categorical variable
## sns.pairplot() data frame , hue = categorical variable, kind = scatter or kde or reg, diag_kind = histogram or kde
sns.pairplot(data=df)
