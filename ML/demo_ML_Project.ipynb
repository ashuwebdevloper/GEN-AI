# %% [markdown]
# Data Gathering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 26.1.2 is available.
# You should consider upgrading via the 'c:\Users\aboyc\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
df = pd.read_csv('C:\\Users\\aboyc\\tutedude\\ML\\International_Education_Costs.csv')

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %% [markdown]
# Data Exploreation

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country'].value_counts()
# Out:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Czech Republic     1
# Hong Kong          1
# Israel             1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['USA', 'UK', 'Canada', 'Australia', 'Germany', 'Japan',
#        'Netherlands', 'Singapore', 'France', 'Switzerland', 'Sweden',
#        'Denmark', 'China', 'South Korea', 'Ireland', 'New Zealand',
#        'Austria', 'Belgium', 'Hong Kong', 'Portugal', 'Israel', 'Taiwan',
#        'Czech Republic', 'India', 'Poland', 'Malaysia', 'Spain', 'Italy',
#        'Finland', 'Norway', 'Brazil', 'Turkey', 'Russia', 'Mexico',
#        'Greece', 'Thailand', 'UAE', 'South Africa', 'Egypt', 'Argentina',
#        'Indonesia', 'Saudi Arabia', 'Nigeria', 'Vietnam', 'Hungary',
#        'Iceland', 'Colombia', 'Romania', 'Luxembourg', 'Tunisia',
#        'Cyprus', 'Croatia', 'Dominican Republic', 'Morocco', 'Peru',
#        'Ecuador', 'Lebanon', 'Bahrain', 'Uruguay', 'Bulgaria', 'Ghana',
#        'Algeria', 'Panama', 'Bangladesh', 'Kuwait', 'Ukraine', 'Slovenia',
#        'Serbia', 'Iran', 'Uzbekistan', 'El Salvador'], dtype=object)

# %%
df[df['Country'] == 'India']
# Out:
#     Country       City                   University                  Program  \
# 44    India  Bangalore  Indian Institute of Science         Computer Science
# 648   India  Bangalore  Indian Institute of Science             Data Science
# 654   India     Mumbai                   IIT Bombay     Computer Engineering
# 659   India      Delhi                    IIT Delhi  Artificial Intelligence
# 665   India    Chennai                   IIT Madras     Software Engineering
# 671   India  Hyderabad                IIT Hyderabad           Data Analytics
# 677   India       Pune                     IIT Pune         Computer Science
# 683   India     Kanpur                   IIT Kanpur  Artificial Intelligence
#
#       Level  Duration_Years  Tuition_USD  Living_Cost_Index  Rent_USD  \
# 44   Master             2.0         2500               45.6       500
# 648     PhD             4.0         2000               45.2       300
# ...

# %%
df['City'].value_counts()
# Out:
# City
# Singapore      18
# Sydney         11
# Melbourne      11
# London         10
# Canberra        8
#                ..
# Penang          1
# Santa Tecla     1
# Andijan         1
# Tabriz          1
# Subotica        1
# Name: count, Length: 556, dtype: int64

# %%
df['Program'].value_counts()
# Out:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64

# %%
df['Level'].value_counts()
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
df['Duration_Years'].min()
# Out:
# np.float64(1.0)

# %%
df.isnull().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Duration_Years'] = df['Duration_Years'].astype('float64')

# %%
df['Tuition_USD'] =  df['Tuition_USD'].astype('int32')
df['Rent_USD']= df['Rent_USD'].astype('int32')
df['Visa_Fee_USD'] = df['Visa_Fee_USD'].astype('int32')
df['Insurance_USD'] = df['Insurance_USD'].astype('int32')

# %%
df.dtypes
# Out:
# Country               object
# City                  object
# University            object
# Program               object
# Level                 object
# Duration_Years       float64
# Tuition_USD            int32
# Living_Cost_Index    float64
# Rent_USD               int32
# Visa_Fee_USD           int32
# Insurance_USD          int32
# Exchange_Rate        float64
# dtype: object

# %% [markdown]
# Exlporatory data analysis

# %%
df['Country'].value_counts().head(10)
# Out:
# Country
# UK             93
# Australia      86
# USA            78
# Canada         76
# Germany        33
# France         27
# South Korea    23
# Netherlands    21
# Switzerland    20
# Singapore      18
# Name: count, dtype: int64

# %%
df[df['Country'].isin(['India', 'China', 'United States', 'United Kingdom', 'Germany', 'Australia', 'France', 'Canada', 'Japan', 'Netherlands'])]
# Out:
#          Country        City                      University  \
# 2         Canada     Toronto           University of Toronto
# 3      Australia   Melbourne         University of Melbourne
# 4        Germany      Munich  Technical University of Munich
# 5          Japan       Tokyo             University of Tokyo
# 6    Netherlands   Amsterdam         University of Amsterdam
# ..           ...         ...                             ...
# 874       France   Marseille        Aix-Marseille University
# 881       France    Bordeaux          University of Bordeaux
# 888       France        Nice              University of Nice
# 895       France       Lille             University of Lille
# 902       France  Strasbourg        University of Strasbourg
#
#                      Program     Level  Duration_Years  Tuition_USD  \
# 2         Business Analytics    Master             2.0        38500
# 3                Engineering    Master             2.0        42000
# ...

# %%
sns.countplot(x='Country', data=df[df['Country'].isin(['India', 'China', 'United States', 'United Kingdom', 'Germany', 'Australia', 'France', 'Canada', 'Japan', 'Netherlands'])])
plt.xticks(rotation=75)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Canada'),
#   Text(1, 0, 'Australia'),
#   Text(2, 0, 'Germany'),
#   Text(3, 0, 'Japan'),
#   Text(4, 0, 'Netherlands'),
#   Text(5, 0, 'France'),
#   Text(6, 0, 'China'),
#   Text(7, 0, 'India')])

# %%
df['City'].value_counts().head(5)
# Out:
# City
# Singapore    18
# Sydney       11
# Melbourne    11
# London       10
# Canberra      8
# Name: count, dtype: int64

# %%
city = df[df['City'].isin(['Singapore', 'Sydney', 'Melbourne',  'London', 'Canberra'])]

# %%
city.shape
# Out:
# (58, 12)

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
d1=df[df['Level'] == 'Master'].head(150)

# %%
d2=df[df['Level'] == 'Bachelor'].head(150)

# %%
d3=df[df['Level'] == 'PhD'].head(150)

# %%
d4=pd.concat([d1,d2,d3], axis=0)

# %%
d4.shape
# Out:
# (450, 12)

# %%
df.shape
# Out:
# (907, 12)

# %%
sns.histplot(x='Duration_Years', data=d4, hue='Level', kde=True)
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='object')

# %%
sns.histplot(data=df, x='Tuition_USD')
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Count'>

# %%
sns.histplot(data=df, x='Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='Rent_USD', hue='Level')
plt.grid()

# %%
sns.boxplot(data=df, x='Level', y='Tuition_USD')
# Out:
# <Axes: xlabel='Level', ylabel='Tuition_USD'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int32
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int32
#  9   Visa_Fee_USD       907 non-null    int32
#  10  Insurance_USD      907 non-null    int32
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int32(4), object(5)
# memory usage: 71.0+ KB

# %%
sns.barplot(data=df, x='Country', y='Tuition_USD')
plt.xticks(rotation=75)
plt.show()
sns.barplot(data=country, x='Country', y='Rent_USD')
plt.xticks(rotation=75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       2 plt.xticks(rotation=75)
#       3 plt.show()
# ----> 4 sns.barplot(data=country, x='Country', y='Rent_USD')
#       5 plt.xticks(rotation=75)
#       6 plt.show()
#
# NameError: name 'country' is not defined

# %%
country.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 country.head()
#
# NameError: name 'country' is not defined

# %%
sns.barplot(data = country, x='Country', y='Tuition_USD')

# %%
df['University'].value_counts()
# Out:
# University
# University of Washington           6
# Stanford University                5
# Australian National University     5
# University of Tasmania             5
# University of Western Australia    5
#                                   ..
# USM                                1
# Universidad Politecnica            1
# Imperial College                   1
# ITCA-FEPADE                        1
# Andijan State University           1
# Name: count, Length: 622, dtype: int64

# %%
df[df['University'].isin(['National University of Singapore', 'University of Sydney', 'University of Melbourne', 'University of London', 'Australian National University', 'University of Toronto', 'University of British Columbia', 'University of Alberta', 'University of Tokyo', 'University of Amsterdam'])]
# Out:
#          Country       City                        University  \
# 2         Canada    Toronto             University of Toronto
# 3      Australia  Melbourne           University of Melbourne
# 5          Japan      Tokyo               University of Tokyo
# 6    Netherlands  Amsterdam           University of Amsterdam
# 7      Singapore  Singapore  National University of Singapore
# 38     Australia   Canberra    Australian National University
# 42        Canada   Edmonton             University of Alberta
# 52        Canada  Vancouver    University of British Columbia
# 53     Australia     Sydney              University of Sydney
# 284       Canada    Toronto             University of Toronto
# 285       Canada    Toronto             University of Toronto
# 286       Canada  Vancouver    University of British Columbia
# 287       Canada  Vancouver    University of British Columbia
# 294       Canada   Edmonton             University of Alberta
# ...

# %%
sns.barplot(data = university, x='Country', y='Tuition_USD')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 sns.barplot(data = university, x='Country', y='Tuition_USD')
#
# NameError: name 'university' is not defined
