# %%
import pandas as pd

# %%
df = pd.read_csv('unclean_smartwatch_health_data.csv')

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %%
df.tail()
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)   Step Count  \
# 9995   1524.0         78.819386               98.931927  2948.491953
# 9996   4879.0         48.632659               95.773035  4725.623070
# 9997   2624.0         73.834442               97.945874  2571.492060
# 9998   4907.0               NaN               98.401058  3364.788855
# 9999   4113.0         70.063864               98.475606   544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9998      5.691233932149209         Active            8
# 9999      5.691001039740254          Actve            5

# %%
df.describe()
# Out:
#            User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count
# count  9799.000000       9600.000000             9700.000000   9900.000000
# mean   3007.480253         76.035462               97.841581   6985.685885
# std    1150.581542         19.412483                1.732863   6885.809680
# min    1001.000000         40.000000               90.791208      0.910138
# 25%    1997.500000         64.890152               96.662683   2021.039657
# 50%    2998.000000         75.220601               98.010642   4962.534599
# 75%    4004.000000         85.198249               99.376179   9724.902880
# max    4999.000000        296.593970              100.000000  62486.690753

# %%
df.isnull().sum()
# Out:
# User ID                   201
# Heart Rate (BPM)          400
# Blood Oxygen Level (%)    300
# Step Count                100
# Sleep Duration (hours)    150
# Activity Level            200
# Stress Level              200
# dtype: int64

# %%
df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool>

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939776               98.809650   5450.390578
# 1      NaN               NaN               98.532195    727.601610
# 2   1860.0        247.803052               97.052954   2826.521994
# 3   2294.0         40.000000               96.894213  13797.338044
# 4   2130.0         61.950165               98.583797  15679.067648
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 1      6.538239375570314  Highly_Active            5
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6

# %% [markdown]
# ## Remove the user od column

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(400)

# %%
df['Heart Rate (BPM)'].value_counts()
# Out:
# Heart Rate (BPM)
# 40.000000     84
# 79.062632      1
# 104.227891     1
# 66.629712      1
# 72.539956      1
#               ..
# 61.367198      1
# 83.545119      1
# 58.797407      1
# 72.505887      1
# 95.372290      1
# Name: count, Length: 9517, dtype: int64

# %%
df[df['Heart Rate (BPM)'] == 296.5939695131042]
# Out:
#       User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 4185   4643.0         296.59397               95.415588  54698.646371
#
#      Sleep Duration (hours) Activity Level Stress Level
# 4185        8.4611474189254            NaN           10

# %%
df['Heart Rate (BPM)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.dropna(subset=['Heart Rate (BPM)'],inplace = True)

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['User ID', 'Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
#        'Sleep Duration (hours)', 'Activity Level', 'Stress Level'],
#       dtype='object')

# %%
df[['Heart Rate (BPM)', 'Blood Oxygen Level (%)', 'Step Count',
       'Sleep Duration (hours)', 'Activity Level', 'Stress Level']]
# Out:
#       Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0            58.939776               98.809650   5450.390578
# 2           247.803052               97.052954   2826.521994
# 3            40.000000               96.894213  13797.338044
# 4            61.950165               98.583797  15679.067648
# 5            96.285938               94.202910  10205.992256
# ...                ...                     ...           ...
# 9994         77.912299               98.640583  10061.145291
# 9995         78.819386               98.931927   2948.491953
# 9996         48.632659               95.773035   4725.623070
# 9997         73.834442               97.945874   2571.492060
# 9999         70.063864               98.475606    544.696104
#
#      Sleep Duration (hours) Activity Level Stress Level
# 0         7.167235622316564  Highly Active            1
# 2                     ERROR  Highly Active            5
# 3         7.367789630207228          Actve            3
# 4                       NaN  Highly_Active            6
# 5         8.378342673824589  Highly_Active           10
# ...                     ...            ...          ...
# 9994      5.428634630125767     Seddentary           10
# 9995      7.402748595032027         Active            7
# 9996     6.3821659358529015      Sedentary            2
# 9997       6.91654920303435      Sedentary            4
# 9999      5.691001039740254          Actve            5
#
# [9600 rows x 6 columns]

# %%
df['Heart Rate (BPM)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9405 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float64
#  2   Blood Oxygen Level (%)  9311 non-null   float64
#  3   Step Count              9506 non-null   float64
#  4   Sleep Duration (hours)  9455 non-null   object
#  5   Activity Level          9409 non-null   object
#  6   Stress Level            9407 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 600.0+ KB

# %%
df['Heart Rate (BPM)']=df['Heart Rate (BPM)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9405 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float32
#  2   Blood Oxygen Level (%)  9311 non-null   float64
#  3   Step Count              9506 non-null   float64
#  4   Sleep Duration (hours)  9455 non-null   object
#  5   Activity Level          9409 non-null   object
#  6   Stress Level            9407 non-null   object
# dtypes: float32(1), float64(3), object(3)
# memory usage: 562.5+ KB

# %%
df['Blood Oxygen Level (%)']=df['Blood Oxygen Level (%)'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9405 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float32
#  2   Blood Oxygen Level (%)  9311 non-null   float32
#  3   Step Count              9506 non-null   float64
#  4   Sleep Duration (hours)  9455 non-null   object
#  5   Activity Level          9409 non-null   object
#  6   Stress Level            9407 non-null   object
# dtypes: float32(2), float64(2), object(3)
# memory usage: 525.0+ KB

# %%
df['Step Count'] = df['Step Count'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9405 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float32
#  2   Blood Oxygen Level (%)  9311 non-null   float32
#  3   Step Count              9506 non-null   float32
#  4   Sleep Duration (hours)  9455 non-null   object
#  5   Activity Level          9409 non-null   object
#  6   Stress Level            9407 non-null   object
# dtypes: float32(3), float64(1), object(3)
# memory usage: 487.5+ KB

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(289)

# %%
df['Blood Oxygen Level (%)'].mean()
# Out:
# np.float32(97.8443)

# %%
df['Blood Oxygen Level (%)'].fillna(97.8443,inplace=True)
# Out:
# C:\Users\aboyc\AppData\Local\Temp\ipykernel_24244\3685568387.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Blood Oxygen Level (%)'].fillna(97.8443,inplace=True)

# %%
df['Blood Oxygen Level (%)'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9600 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   User ID                 9405 non-null   float64
#  1   Heart Rate (BPM)        9600 non-null   float32
#  2   Blood Oxygen Level (%)  9600 non-null   float32
#  3   Step Count              9506 non-null   float32
#  4   Sleep Duration (hours)  9455 non-null   object
#  5   Activity Level          9409 non-null   object
#  6   Stress Level            9407 non-null   object
# dtypes: float32(3), float64(1), object(3)
# memory usage: 487.5+ KB

# %%
df.head()
# Out:
#    User ID  Heart Rate (BPM)  Blood Oxygen Level (%)    Step Count  \
# 0   4174.0         58.939777               98.809647   5450.390625
# 2   1860.0        247.803055               97.052956   2826.521973
# 3   2294.0         40.000000               96.894211  13797.337891
# 4   2130.0         61.950165               98.583794  15679.067383
# 5   2095.0         96.285934               94.202911  10205.992188
#
#   Sleep Duration (hours) Activity Level Stress Level
# 0      7.167235622316564  Highly Active            1
# 2                  ERROR  Highly Active            5
# 3      7.367789630207228          Actve            3
# 4                    NaN  Highly_Active            6
# 5      8.378342673824589  Highly_Active           10

# %%
df.dropna(subset=['Step Count'],inplace=True)

# %%
df['Step Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# ERROR                 234
# 5.224139066195455       1
# 5.468413771417153       1
# 7.9544989905339145      1
# 7.541956463173237       1
#                      ...
# 7.331498224681581       1
# 8.830228464836619       1
# 8.035879532058063       1
# 3.691697829588543       1
# 8.378342673824589       1
# Name: count, Length: 9129, dtype: int64

# %%
df = df[df['Sleep Duration (hours)']!='ERROR']

# %%
df['Sleep Duration (hours)'].value_counts()
# Out:
# Sleep Duration (hours)
# 5.691001039740254    1
# 7.167235622316564    1
# 7.367789630207228    1
# 8.378342673824589    1
# 7.871146008904113    1
#                     ..
# 6.392173806051382    1
# 6.444869604525839    1
# 6.269060283034982    1
# 5.814348465914493    1
# 4.830161671840198    1
# Name: count, Length: 9128, dtype: int64

# %%
df['Sleep Duration (hours)'] = df['Sleep Duration (hours)'].astype('float32')

# %%
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(12.140233)

# %% [markdown]
# ## how to remove the outliers

# %%
df = df[df['Sleep Duration (hours)']<12.0]

# %%
df['Sleep Duration (hours)'].max()
# Out:
# np.float32(11.908386)

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(187)

# %%
df.dropna(subset=['Activity Level'],inplace = True)

# %%
df['Activity Level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Stress Level'].dtype
# Out:
# dtype('O')

# %%
df['Stress Level'].value_counts()
# Out:
# Stress Level
# 2            908
# 6            896
# 1            893
# 7            892
# 3            889
# 4            868
# 9            865
# 5            848
# 10           839
# 8            817
# Very High     42
# Name: count, dtype: int64

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(183)

# %%
df['Stress Level'].fillna(5,inplace=True)
# Out:
# C:\Users\aboyc\AppData\Local\Temp\ipykernel_24244\1190028874.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Stress Level'].fillna(5,inplace=True)

# %%
df['Stress Level'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Lang chain basic ai apps , Lang Graph complex ai apps

# %% [markdown]
# ### Data cleaning -->   stopword removal lower casing , stemming, lemetisation

# %% [markdown]
# ## for automated data cleaning we use simple imputor

# %% [markdown]
# # MCAR --. Missing completly st random no pattern
# # MAR    -- > yes pattern KNN
# # MNAR  -- > no pattern
