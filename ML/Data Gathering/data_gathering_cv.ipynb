# %% [markdown]
# ## Data Gathering

# %% [markdown]
# pd.read_csv

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\aboyc\tutedude\ML\Data Gathering\katalog_gempa_v2.tsv')

# %%
df
# Out:
#                                                    eventID\tdatetime\tlatitude\tlongitude\tmagnitude\tmag_type\tdepth\tphasecount\tazimuth_gap\tlocation\tagency\tdatetimeFM\tlatFM\tlonFM\tmagFM\tmagTypeFM\tdepthFM\tphasecountFM\tAzGapFM\tscalarMoment\tMrr\tMtt\tMpp\tMrt\tMrp\tMtp\tvarianceReduction\tdoubleCouple\tclvd\tstrikeNP1\tdipNP1\trakeNP1\tstrikeNP2\tdipNP2\trakeNP2\tazgapFM\tmisfit
# bmg2008vkye\t2008-11-01 00:31:25.143741+00:00\t...   Indonesia\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# bmg2008vlag\t2008-11-01 01:34:29.660856+00:00\t...                                                NaN
# bmg2008vlaj\t2008-11-01 01:38:14.802129+00:00\t...   Indonesia\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# bmg2008vlbt\t2008-11-01 02:20:05.909515+00:00\t...                                                NaN
# bmg2008vlcd\t2008-11-01 02:32:18.756155+00:00\t...                                                NaN
# ...

# %%
df = pd.read_csv(r'C:\Users\aboyc\tutedude\ML\Data Gathering\Titanic-Dataset.csv',names=['P_ID','Survived','Pclass','P_name','Gender','Age','Sibiling or Spouse','Parch','Ticket_ID','Fare','Cabin','Starting Journey'])

# %%
df
# Out:
#             P_ID  Survived  Pclass  \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                 P_name  Gender  Age  \
# 0                                                 Name     Sex  Age
# 1                              Braund, Mr. Owen Harris    male   22
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                               Heikkinen, Miss. Laina  female   26
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# ..                                                 ...     ...  ...
# ...

# %%
df.columns = df.iloc[0]
df = df[1:].reset_index(drop=True).set_index('PassengerId')

# %%
df_student = pd.read_csv('student_depression_dataset.csv')

df_student = df_student.rename(columns={
    'Gender': 'gender',
    'Age': 'age',
    'City': 'city',
    'Profession': 'profession',
    'Academic Pressure': 'academic_pressure',
    'CGPA': 'cgpa',
    'Study Satisfaction': 'study_satisfaction',
    'Job Satisfaction': 'job',
    'Sleep Duration': 'sleep_duration',
    'Dietary Habits': 'dietary_habits',
    'Degree': 'degree_satisfaction',
    'Have you ever had suicidal thoughts ?': 'have_you_ever_had_suicidal_thoughts',
    'Depression': 'depression'
})[cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 17
#       1 df_student = pd.read_csv('student_depression_dataset.csv')
#       3 df_student = df_student.rename(columns={
#       4     'Gender': 'gender',
#       5     'Age': 'age',
#       6     'City': 'city',
#       7     'Profession': 'profession',
#       8     'Academic Pressure': 'academic_pressure',
#       9     'CGPA': 'cgpa',
#      10     'Study Satisfaction': 'study_satisfaction',
#      11     'Job Satisfaction': 'job',
#      12     'Sleep Duration': 'sleep_duration',
#      13     'Dietary Habits': 'dietary_habits',
#      14     'Degree': 'degree_satisfaction',
#      15     'Have you ever had suicidal thoughts ?': 'have_you_ever_had_suicidal_thoughts',
#      16     'Depression': 'depression'
# ---> 17 })[cols]
#
# NameError: name 'cols' is not defined

# %%
df
# Out:
# 0           Survived Pclass  \
# PassengerId
# 1                  0      3
# 2                  1      1
# 3                  1      3
# 4                  1      1
# 5                  0      3
# ...              ...    ...
# 887                0      2
# 888                1      1
# 889                0      3
# 890                1      1
# 891                0      3
#
# 0                                                         Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# ...                                                        ...     ...  ...
# ...

# %%
cols = [
    'id', 'gender', 'age', 'city', 'profession',
    'academic_pressure', 'cgpa', 'study_satisfaction',
    'job', 'sleep_duration', 'dietary_habits',
    'degree_satisfaction',
    'have_you_ever_had_suicidal_thoughts',
    'depression'
]

df_student = pd.read_csv('student_depression_dataset.csv')
df_student.columns = cols
d
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 11
#       1 cols = [
#       2     'id', 'gender', 'age', 'city', 'profession',
#       3     'academic_pressure', 'cgpa', 'study_satisfaction',
#    (...)
#       7     'depression'
#       8 ]
#      10 df_student = pd.read_csv('student_depression_dataset.csv')
# ---> 11 df_student.columns = cols
#      12 d
#
# File c:\Users\aboyc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
df = pd.read_csv(r'C:\Users\aboyc\tutedude\ML\Data Gathering\Titanic-Dataset.csv',usecols=['Survived']).squeeze()

# %%
df
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
pd.read_csv('Titanic-Dataset.csv', encoding='latin-1')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv('student_depression_dataset.csv',dtype={'Age':int,'Work Pressure':int})
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                5.0
# 1           8  Female   24      Bangalore    Student                2.0
# 2          26    Male   31       Srinagar    Student                3.0
# 3          30  Female   28       Varanasi    Student                3.0
# 4          32  Female   25         Jaipur    Student                4.0
# ...       ...     ...  ...            ...        ...                ...
# 27896  140685  Female   27          Surat    Student                5.0
# 27897  140686    Male   27       Ludhiana    Student                2.0
# 27898  140689    Male   31      Faridabad    Student                3.0
# 27899  140690  Female   18       Ludhiana    Student                5.0
# 27900  140699    Male   27          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
pd.read_csv('student_depression_dataset.csv',dtype={'Age':int,'Work Pressure':int})
