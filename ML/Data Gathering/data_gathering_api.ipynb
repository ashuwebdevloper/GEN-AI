# %% [markdown]
# ## Data Gathering using api

# %%
import sys

try:
    import requests
except ModuleNotFoundError:
    # !{sys.executable} -m pip install requests
    import requests
# Out:
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\aboyc\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\aboyc\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ysql-connector-python (c:\users\aboyc\appdata\local\programs\python\python310\lib\site-packages)
#   WARNING: The script idna.exe is installed in 'c:\Users\aboyc\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\aboyc\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
