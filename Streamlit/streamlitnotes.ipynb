# %% [markdown]
# it is an open source python library used to built beautifool interactive web for data science an ml with less effort

# %% [markdown]
# it is easy to use fast devlopmet we initeractive uui elment buttonos sliders text charts etc
#
# great for data science supports pandas matplolib ploty and other librairs
# deeploymnet is easy
