# %%
f = open('example.txt', 'r')
content = f.read()
print(content)
f.close()
# Out:
# Hello my name is ashish and i am leaning python as my pre requisite it willl help me alot

# %%
f = open('example.txt', 'w')
f.write('This is a new line.\n')
f.write('This is another line.\n')
f.close()
print('File written successfully.')
# Out:
# File written successfully.

# %%
f = open ('example.txt','a')
f.write('\n This line is appended to the file.  ')
f.close()
print('Line appended successfully.')
# Out:
# Line appended successfully.

# %%
with open('example.txt', 'r') as f:
    content = f.read()
    print(content)
# Out:
# This is a new line.
# This is another line.
#
#  This line is appended to the file.

# %%
with open('example.txt', 'a') as file:
    file.write('\n This line is appended using with statement. ')
print('Line appended successfully using with statement.')

# %%
lines = ['First line.\n', 'Second line.\n', 'Third line.\n']
with open('example.txt', 'w') as f:
    f.writelines(lines)

# %%
data = b'\x00\x01\x02\x03\x04'
with open('example.txt', 'wb') as f:
    f.write(data)

# %%
with open('example.txt', 'rb') as f:
    binary_content = f.read()
    print(binary_content)
# Out:
# b'\x00\x01\x02\x03\x04'

# %%
### reading from source and writing in  requirment

# %%
with open('example.txt', 'r') as f:
    content = f.read()

with open('new_example.txt', 'w') as f:
    f.write(content)
print('File written successfully.')
# Out:
# File written successfully.

# %%
def count_lines(file):
    with open(file,'r') as files:
        lines = files.readlines()
        total_lines = len(lines)
        total_words = sum(len(line.split()) for line in lines)
        total_characters = sum(len(lie) for line in lines)
    return total_characters, total_lines, total_words

file_path = 'Total_data.txt'
print

# %% [markdown]
# w+   first writing the afterthat reading same for r+
# seek()---> it helps out with reading the content from the starting only

# %%
with open('Total_Data.txt','w+') as write_read_file:
    write_read_file.write("\n we arw looking into w+ operation ")
    write_read_file.seek(0)
    content_complete_data = write_read_file.read()
