# %% [markdown]
# **Lambda functions**

# %%
def square(num):
    return num**2

# %%
print(square(5))
# Out:
# 25

# %%
lambda x:x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
square = lambda x:x**2
type(square)
# Out:
# function

# %%
square(7)
# Out:
# 49

# %%
sum = lambda a,b:a+b
print(sum(3,4))
# Out:
# 7
