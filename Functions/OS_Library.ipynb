# %%
import os

# %%
current_path = os.getcwd()
print("The current working directory is :", current_path)
# Out:
# The current working directory is : c:\Users\aboyc\tutedude\Functions

# %%
new_path="New_folder"
os.mkdir(new_path)
print(f"the new directory {new_path} is created")
# Out:
# the new directory New_folder is created

# %%
All_items = os.listdir('.')
print(All_items)
# Out:
# ['example.txt', 'file_handling.ipynb', 'Filter_functio.ipynb', 'functions.ipynb', 'functions_examples.ipynb', 'lambda_functions.ipynb', 'Map.ipynb', 'new_example.txt', 'New_folder', 'OS_Library.ipynb', 'source.txt', 'Total_Data.txt']

# %%
dir_name = "Folder_data"
file_name = "File_data"
Full_path = os.path.join(dir_name, file_name)
print(f"The path of the file is : {Full_path}")
# Out:
# The path of the file is : Folder_data\File_data

# %%
current_complete_path = os.path.join(os.getcwd(), file_name)
print(f"The complete path of the file is : {current_complete_path}")

# %%
path = 'Total_Data.txt'

if os.path.isfile(path):
    print(f"The file {path} exists")
elif os.path.isdir(path):
    print(f"The path {path} is a directory")
else:
    print(f"The path {path} does not exist")
# Out:
# The file Total_Data.txt exists

# %%
file_name =  'Total_Data.txt'
complete_path = os.path.abspath(file_name)
print(f"The complete path of the file is : {complete_path}")
# Out:
# The complete path of the file is : c:\Users\aboyc\tutedude\Functions\Total_Data.txt
