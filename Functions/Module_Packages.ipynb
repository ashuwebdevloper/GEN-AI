# %% [markdown]
# *Module Packages*

# %% [markdown]
# a module in python is a simple is simply a file containing python code (functions classes vaiables ) that can be imported and used in other programns

# %%
import numpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import os

# %%
import math

# %%
import pkgutil
import sys

print("Built-in modules:")
print(sorted(sys.builtin_module_names))

print("\nInstalled modules/packages:")
for module in sorted(pkgutil.iter_modules(), key=lambda m: m.name):
    print(module.name)
# Out:
# Built-in modules:
# ['_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_symtable', '_thread', '_tracemalloc', '_warnings', '_weakref', '_winapi', '_xxsubinterpreters', 'array', 'atexit', 'audioop', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib']
#
# Installed modules/packages:
# IPython
# __future__
# _aix_support
# _asyncio
# _bootsubprocess
# _bz2
# _collections_abc
# _compat_pickle
# _compression
# _ctypes
# _ctypes_test
# _decimal
# _distutils_hack
# _elementtree
# _hashlib
# ...

# %%
from package_folder.mathematics import substraction

# %%
addition(5, 10)
# Out:
# 15

# %%
substraction(10, 5)
# Out:
# 5
