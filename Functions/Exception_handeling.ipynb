# %% [markdown]
# ## Exception Handling

# %%
print("Hello please dont provide denominator value as zero" \
"")

denominator = int(input("Hello enter the denominator: "))
if denominator == 0:
    print("Error: Denominator cannot be zero.")
else:
    result = 10 / denominator
    print(result)
# Out:
# Hello please dont provide denominator value as zero
# 2.0

# %% [markdown]
# exception handelling is which if we are getting the error in programming
# exception ar eevent that disruoptdd the normal occur ace of program whrn the progrma is bieng exected
